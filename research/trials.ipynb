# %%
print("hi")
# Out:
# hi

# %%
print("hello")
# Out:
# hello

# %%
dict = {"name": "John", "age": 30, "city": "New York"}
print(dict["name"])
# Out:
# John

# %%
from box import ConfigBox

dict2 = ConfigBox({"name":"jesus_of_nazereth", "age": "invincible", "city": "heaven"})

dict2.age
# Out:
# 'invincible'

# %%
dict2.name
# Out:
# 'jesus_of_nazereth'
